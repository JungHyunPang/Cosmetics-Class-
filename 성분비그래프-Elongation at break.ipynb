# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
gap = 0.01
xmin, xmax, ymin, ymax, zmin, zmax = 0, 2, 0, 2, 0, 2

# %%
xs = []
ys = []
zs = []
fs = []
alpha = 4.3
beta = 68.
gamma = 5.2
for i in range(101):
    x = gap * i
    for j in range(101):
        for k in range(101):
            if i+j+k == 100:                
                y = gap*j
                z = 1. - x - y
                f = alpha * x + beta * y + gamma*z
                xs.append(x)
                ys.append(y)
                zs.append(z)
                fs.append(f)

# %%
cmin = min(fs)
cmax = max(fs)
print(cmin, cmax)
# Out:
# 4.3 68.0

# %%
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c=fs, marker='o', s=15, cmap='Oranges')
ax.view_init(30, 30)

plt.show()
